# %% [markdown]
# # <center>EPIB 613 INTRODUCTION TO STATISTICAL SOFTWARE</center>
#
# <center> McGill EBOH </center>
#
# <center> Fall 2020 </center>
#
# <center> Yi Lian </center>
#
# # Lecture 10
# - More exercise on reshaping data √
# - Preparing for coverage probability (EPIB 607)
#     - Distributions √
#     - <tt>apply()</tt>
# - Coverage probability

# %% [markdown]
# ## 3. The <tt>apply()</tt> family
# - <tt>apply()</tt>
# - <tt>lapply()</tt>
# - <tt>tapply()</tt>
# - <tt>sapply()</tt>
# - <tt>vapply()</tt>
# - <tt>mapply()</tt>
# - <tt>replicate()</tt>
#
# #### There are similar ones in the package <tt>plyr</tt>
# - <tt>adply()</tt>
# - <tt>ddply()</tt>
# - <tt>ldply()</tt>
# - ...

# %% [markdown]
# ### 3.1 <tt>apply()</tt>

# %%
mat <- matrix(1:6, nrow = 2); mat
# Out:
#      [,1] [,2] [,3]
# [1,] 1    3    5
# [2,] 2    4    6

# %%
apply(mat, MARGIN = 1, FUN = sum)
# Out:
# [1]  9 12

# %%
apply(mat, MARGIN = 2, FUN = sum)
# Out:
# [1]  3  7 11

# %%
myarray <- array(1:12, dim = c(2,3,2)); print(myarray)
# Out:
# , , 1
#
#      [,1] [,2] [,3]
# [1,]    1    3    5
# [2,]    2    4    6
#
# , , 2
#
#      [,1] [,2] [,3]
# [1,]    7    9   11
# [2,]    8   10   12

# %%
apply(myarray, MARGIN = 1, FUN = sum)
# Out:
# [1] 36 42

# %%
# What happened?
apply(myarray, MARGIN = c(1, 3), FUN = sum)
# Out:
#      [,1] [,2]
# [1,]  9   27
# [2,] 12   30

# %% [markdown]
# ### 3.2 <tt>lapply()</tt>
# list apply

# %%
set.seed(613)
scores <- round(runif(n = 20, min = 50, max = 100)); scores
# Out:
#  [1] 99 98 55 91 66 97 78 95 59 72 81 68 70 62 80 85 61 64 52 54

# %%
groups <- cut(scores,
              breaks = c(-Inf, 65, 70, 75, 80, 85, Inf),
              labels = c("F", "B-", "B", "B+", "A-", "A"))
groups
# Out:
#  [1] A  A  F  A  B- A  B+ A  F  B  A- B- B- F  B+ A- F  F  F  F
# Levels: F B- B B+ A- A

# %%
score.list <- split(scores, f = groups)

# set one value to NA for teaching purpose
score.list$A[5] <- NA
score.list
# Out:
# $F
# [1] 55 59 62 61 64 52 54
#
# $`B-`
# [1] 66 68 70
#
# $B
# [1] 72
#
# $`B+`
# [1] 78 80
#
# $`A-`
# [1] 81 85
#
# $A
# [1] 99 98 91 97 NA

# %%
# Average for each letter grade
lapply(score.list, FUN = mean)
# Out:
# $`C+`
# [1] 58.14286
#
# $`B-`
# [1] 68
#
# $B
# [1] 72
#
# $`B+`
# [1] 79
#
# $`A-`
# [1] 83
#
# $A
# [1] NA

# %%
lapply(score.list, FUN = mean, na.rm = T)
# Out:
# $`C+`
# [1] 58.14286
#
# $`B-`
# [1] 68
#
# $B
# [1] 72
#
# $`B+`
# [1] 79
#
# $`A-`
# [1] 83
#
# $A
# [1] 96.25

# %% [markdown]
# ### 3.3 <tt>sapply()</tt>

# %%
# sapply on a list
sapply(score.list, FUN = mean)
# Out:
#       C+       B-        B       B+       A-        A
# 58.14286 68.00000 72.00000 79.00000 83.00000       NA

# %%
sapply(score.list, FUN = mean, na.rm = T, simplify = F)
# Out:
# $`C+`
# [1] 58.14286
#
# $`B-`
# [1] 68
#
# $B
# [1] 72
#
# $`B+`
# [1] 79
#
# $`A-`
# [1] 83
#
# $A
# [1] 96.25

# %%
# sapply() on a data frame
head(iris)
sapply(iris, FUN = class)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa
# Sepal.Length  Sepal.Width Petal.Length  Petal.Width      Species
#    "numeric"    "numeric"    "numeric"    "numeric"     "factor"

# %%
# sapply on a vector
sapply(c(6, 1, 3), FUN = seq)
# Out:
# [[1]]
# [1] 1 2 3 4 5 6
#
# [[2]]
# [1] 1
#
# [[3]]
# [1] 1 2 3

# %%
# sapply an operator instead of a function
sapply(c(6, 1, 3), FUN = '+', 2)
# Out:
# [1] 8 3 5

# %%
# use our own function in FUN
sapply(c(6, 1, 3), FUN = function(x) {x + 2})
# Out:
# [1] 8 3 5

# %%
# plyr::ldply
plyr::ldply(`.data` = c(6, 1, 3), `.fun` = function(x) {x + 2})
# Out:
#   V1
# 1 8
# 2 3
# 3 5

# %% [markdown]
# ##### Exercise.
# 1. Use <tt>plyr::ldply</tt>, find out how many students there are in each letter grade.

# %%
score.list
# Out:
# $`C+`
# [1] 55 59 62 61 64 52 54
#
# $`B-`
# [1] 66 68 70
#
# $B
# [1] 72
#
# $`B+`
# [1] 78 80
#
# $`A-`
# [1] 81 85
#
# $A
# [1] 99 98 91 97 NA

# %% [markdown]
# ### 3.4 <tt>tapply()</tt>

# %%
# recall aggregate()
aggregate(Sepal.Length~Species, FUN = mean, data = iris)
# Out:
#   Species    Sepal.Length
# 1 setosa     5.006
# 2 versicolor 5.936
# 3 virginica  6.588

# %%
# Alternative syntax
aggregate(iris$Sepal.Length, by = list(Species = iris$Species), FUN = mean)
# Out:
#   Species    x
# 1 setosa     5.006
# 2 versicolor 5.936
# 3 virginica  6.588

# %%
tapply(X = iris$Sepal.Length, INDEX = list(Species = iris$Species), FUN = mean)
# Out:
# Species
#     setosa versicolor  virginica
#      5.006      5.936      6.588

# %%
# Another function that does the same thing
by(data = iris$Sepal.Length, INDICES = list(Species = iris$Species), FUN = mean)
# Out:
# Species: setosa
# [1] 5.006
# ------------------------------------------------------------
# Species: versicolor
# [1] 5.936
# ------------------------------------------------------------
# Species: virginica
# [1] 6.588

# %% [markdown]
# ### 3.5 <tt>replicate()</tt>

# %%
aaa_x10 <- replicate(n = 10, expr = {
    "aaa"
})
aaa_x10
# Out:
#  [1] "aaa" "aaa" "aaa" "aaa" "aaa" "aaa" "aaa" "aaa" "aaa" "aaa"

# %%
replicate(n = 5, expr = {
    rnorm(n = 2)
})
# Out:
#      [,1]      [,2]       [,3]      [,4]       [,5]
# [1,] 0.6453831 -0.3043691 0.9712207  0.6720425 0.5365237
# [2,] 1.0431436  2.4771109 1.8670992 -0.3079534 0.8248701

# %% [markdown]
# ## 4. Coverage probability (EPIB 607)
#
# ##### Exercise: what is interpretation of a confidence interval?
#
# ### 4.1 Midterm question

# %%
library(plyr)
library(dplyr)
library(ggplot2)
library(mosaic)
yrbss <- readr::read_csv(file = "/Users/YLIAN/Desktop/Teaching/EPIB613/2020/yrbss.csv")
set.seed(234)
number.samples <- 25

# Draw 25 samples of size 16 each and calculate 80%, 96% t-based confidence intervals
mu <- mean(yrbss$weight)
R.16.80.96 <- replicate(number.samples, {
    sample.16 <- yrbss %>%
        dplyr::sample_n(size = 16) %>%
        dplyr::pull(weight)
    
    c(t.test(sample.16, conf.level = .80)$conf.int,
      t.test(sample.16, conf.level = .96)$conf.int)
}) %>% t()

# check coverage for 80% interval
mean(sapply(1:number.samples,
            FUN = function(i) {
                (mu >= R.16.80.96[i,1]) & (mu <= R.16.80.96[i,2])
            }
    )
)
# Out:
# ── Column specification ────────────────────────────────────────────────────────
# cols(
#   age = col_double(),
#   gender = col_character(),
#   height = col_double(),
#   weight = col_double(),
#   hispanic = col_logical(),
#   race = col_character(),
#   physically.active.7d = col_double(),
#   hours.tv.per.school.day = col_character(),
#   strength.training.7d = col_double()
# )
# [1] 0.84

# %%
# check coverage for 96% interval
mean(sapply(1:number.samples, function(i){
(mu >= R.16.80.96[i,3]) & (mu <= R.16.80.96[i,4])
}))
# Out:
# [1] 0.96

# %%
par(mfrow = c(1,2))
plot(range(R.16.80.96), c(1, number.samples),
     col="black", typ="n",
     main = "80% Confidence Interval",
     ylab="Samples",
     xlab="Mean Weight (kg)")

segments(R.16.80.96[,1], 1:number.samples, R.16.80.96[,2], 1:number.samples)
abline(v = mu, lty = 2, col = "red")

plot(range(R.16.80.96), c(1, number.samples), col="black", typ="n",
    main = "96% Confidence Interval", ylab="Samples",
    xlab="Mean Weight (kg)")
segments(R.16.80.96[,3], 1:number.samples, R.16.80.96[,4], 1:number.samples)
abline(v = mu, lty = 2, col = "red")
# Out:
# Plot with title “96% Confidence Interval”

# %% [markdown]
# ### 4.2 Coverage probability for Poisson counts

# %%
# possion based CI
set.seed(12345)
true_lambda <- 6
sims <- rpois(100, lambda = true_lambda)
df <- plyr::ldply(sims, function(i) {
    z_ci <- poisson.test(x = i, T = 1)$conf.int
    c(z_ci,i, dplyr::between(true_lambda, z_ci[1],z_ci[2]))
})

df$trial <- factor(seq_along(df$V1))
colnames(df) <- c("lower","upper","mean", "covered", "trial")
df$covered <- factor(df$covered, levels = 0:1, labels = c("no","yes"))
df$width <- df$upper - df$lower

p <- ggplot(df, aes(mean, trial, colour = covered))
p + geom_point() +
    geom_errorbarh(aes(xmax = upper, xmin = lower)) +
    geom_vline(xintercept = true_lambda) +
    theme_bw(base_size = 13L) +
    labs(caption = sprintf("average CI width is %0.2f", median(df$width)))
# Out:
# plot without title

# %%
set.seed(12345)
true_lambda <- 6
sims <- rpois(100, lambda = true_lambda)
df <- plyr::ldply(sims, function(i) {
  z_ci <- qnorm(p = c(0.025, 0.975), mean = i, sd = sqrt(i)) 
  c(z_ci,i, dplyr::between(true_lambda, z_ci[1],z_ci[2]))
}) 

df$trial <- factor(seq_along(df$V1))
colnames(df) <- c("lower","upper","mean", "covered", "trial")
df$covered <- factor(df$covered, levels = 0:1, labels = c("no","yes"))
df$width <- df$upper - df$lower

p <- ggplot(df, aes(mean, trial, colour = covered))
p + geom_point() +
    geom_errorbarh(aes(xmax = upper, xmin = lower)) +
    geom_vline(xintercept = true_lambda) + 
    theme_bw(base_size = 13L) +
    labs(caption = sprintf("average CI width is %0.2f", mean(df$width)))
# Out:
# plot without title
